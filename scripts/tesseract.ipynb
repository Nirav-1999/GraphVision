# %%
import pytesseract
import cv2
import os

# %%
img_path = "/home/nirav/Desktop/Workspace/ML/DJ_Strike/test_images_bar/30_out.png"

# %%
img = cv2.imread(img_path)
# img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("image",gray)

# %%
img_data = pytesseract.image_to_data(gray,output_type='data.frame')

# %%
img_data.dropna(subset=['text'],inplace=True)

# %%
img_data
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 4       5         1          1        1         1         1    54   28     13
# 8       5         1          2        1         1         1    53   77     14
# 12      5         1          3        1         1         1    54  126     13
# 16      5         1          4        1         1         1    53  175     14
# 20      5         1          5        1         1         1    54  224     13
# 24      5         1          6        1         1         1    53  273     14
# 28      5         1          7        1         1         1    54  322     13
# 32      5         1          8        1         1         1    73   30    434
# 36      5         1          9        1         1         1    72   31      3
# 40      5         1         10        1         1         1    73  372    434
# 44      5         1         11        1         1         1   145  384      4
# ...

# %%
img_data = img_data[img_data['text']!=' ']
img_data
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 4       5         1          1        1         1         1    54   28     13
# 8       5         1          2        1         1         1    53   77     14
# 12      5         1          3        1         1         1    54  126     13
# 16      5         1          4        1         1         1    53  175     14
# 20      5         1          5        1         1         1    54  224     13
# 24      5         1          6        1         1         1    53  273     14
# 28      5         1          7        1         1         1    54  322     13
# 44      5         1         11        1         1         1   145  384      4
# 45      5         1         11        1         1         2   215  384      7
# 46      5         1         11        1         1         3   287  384      6
# 47      5         1         11        1         1         4   357  384      7
# ...

# %%
key = cv2.waitKey()
if key==27:
    cv2.destroyAllWindows()
